# %%
from sampling import linear, chebyshev, offset_left
from ColourgridGenerator import ColourgridGenerator
import matplotlib.pyplot as plt

tl = 0xEF476F
tr = 0xFFD166
br = 0x06D6A0
bl = 0x118AB2

cols = ColourgridGenerator(num_rows=100, num_cols=100, top_left=tl, top_right=tr, bottom_right=br, bottom_left=bl)
grid = cols.generate(linear)

fig, ax = plt.subplots()
ax.axis('off')
fig.set_size_inches(12,12)
ax.imshow(grid,vmin=0, vmax=255)
plt.show()
