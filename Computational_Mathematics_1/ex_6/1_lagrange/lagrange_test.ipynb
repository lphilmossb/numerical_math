# %%
from Lagrange import LagrangeInterpPoly
import numpy as np
import matplotlib.pyplot as plt


x_data = np.array([0, 0.5, 1, 1.5])
y_data = np.array([1, 2, 3, 4])
x = np.linspace(0, 1.5, 100)

plt.rcParams.update({
    'font.size': 18
})

def pn_header(n)->str:
    rval = 'x,p,'
    for i in range(n):
        rval += f'l{i+1}'
        if i != n-1:
            rval += ','
    return rval

fig, ax = plt.subplots()
LagrangeInterpPoly(x_data, y_data, ax)
ax.grid()
ax.legend()
fig.set_size_inches(12,12)
plt.show()
# np.savetxt('interpolating.csv', np.column_stack((x,pn,base)), header=pn_header(4), comments='', delimiter=',')
