# %%
import numpy as np
import matplotlib.pyplot as plt

eps = 1e-12
res = 500

x = np.linspace(-eps,eps,res)

g = x**2
f = np.abs(np.sinc(1.0/np.pi * x) - 1)

plt.plot(x,g)
plt.plot(x,f)

plt.show()
